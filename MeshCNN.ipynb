# %% [markdown]
# <a href="https://colab.research.google.com/github/christinezuzart/MeshCNN_Tests/blob/master/MeshCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi 
# !pip install gputil 
# !pip install psutil
# !pip install humanize
import psutil 
import humanize 
import os 
import GPUtil as GPU 
GPUs = GPU.getGPUs()

# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0] 
def printm(): 
  process = psutil.Process(os.getpid())
  print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss)) 
  print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal)) 

printm()
# Out:
# ...
# Gen RAM Free: 12.8 GB  | Proc size: 156.6 MB
# GPU RAM Free: 15079MB | Used: 0MB | Util   0% | Total 15079MB

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
import torch

print(torch.__version__)
# Out:
# 1.3.1

# %%
# !pip install tensorboardX

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %%
import tensorboardX
print(tensorboardX.__version__)
# Out:
# 2.0

# %%
# %cd drive/My Drive/meshcnn_project
# Out:
# /content/drive/My Drive/meshcnn_project

# %%
! git clone https://github.com/ranahanocka/MeshCNN.git
# Out:
# fatal: destination path 'MeshCNN' already exists and is not an empty directory.

# %%
# %cd MeshCNN
# Out:
# /content/drive/My Drive/meshcnn_project/MeshCNN

# %%
! ./scripts/shrec/get_data.sh
# Out:
# /bin/bash: ./scripts/shrec/get_data.sh: /usr/bin/env: bad interpreter: Permission denied

# %%
# %mkdir -p datasets

# %%
# %cd datasets
# Out:
# /content/drive/My Drive/meshcnn_project/MeshCNN/datasets

# %%
# !wget https://www.dropbox.com/s/w16st84r6wc57u7/shrec_16.tar.gz
# Out:
# --2020-01-31 08:49:05--  https://www.dropbox.com/s/w16st84r6wc57u7/shrec_16.tar.gz
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/w16st84r6wc57u7/shrec_16.tar.gz [following]
# --2020-01-31 08:49:05--  https://www.dropbox.com/s/raw/w16st84r6wc57u7/shrec_16.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb82b546b4a6baa75d962164375.dl.dropboxusercontent.com/cd/0/inline/AxOulQS7iYJ-vB8iNLARGIJl1vA3_dzFXQ_Kb-6BugiKYv0AqbcNTA9ZAYAboj1u4Lh8y6nHrMlSZ-vBWp3amWNjD-fdbUCXk4tb02NeUF9DkOLcIUbJraLXMF_SpnRXb2I/file# [following]
# ...

# %%
# !tar -xzvf shrec_16.tar.gz && rm shrec_16.tar.gz
# Out:
# shrec_16/
# shrec_16/lamp/
# shrec_16/lamp/train/
# shrec_16/lamp/train/T132.obj
# shrec_16/lamp/train/T194.obj
# shrec_16/lamp/train/T71.obj
# shrec_16/lamp/train/T121.obj
# shrec_16/lamp/train/T165.obj
# shrec_16/lamp/train/T122.obj
# shrec_16/lamp/train/T396.obj
# shrec_16/lamp/train/T16.obj
# shrec_16/lamp/train/T262.obj
# shrec_16/lamp/train/T346.obj
# shrec_16/lamp/train/T185.obj
# shrec_16/lamp/train/T596.obj
# shrec_16/lamp/train/T183.obj
# shrec_16/lamp/train/T202.obj
# shrec_16/lamp/train/T324.obj
# shrec_16/lamp/train/T91.obj
# shrec_16/lamp/test/
# shrec_16/lamp/test/T113.obj
# shrec_16/lamp/test/T63.obj
# shrec_16/lamp/test/T237.obj
# shrec_16/lamp/test/T427.obj
# shrec_16/shark/
# shrec_16/shark/train/
# shrec_16/shark/train/T268.obj
# shrec_16/shark/train/T516.obj
# shrec_16/shark/train/T241.obj
# shrec_16/shark/train/T291.obj
# shrec_16/shark/train/T323.obj
# shrec_16/shark/train/T456.obj
# shrec_16/shark/train/T394.obj
# shrec_16/shark/train/T289.obj
# ...

# %%
# %cd ..
# Out:
# /content/drive/My Drive/meshcnn_project/MeshCNN

# %%
! ./scripts/shrec/train.sh
# Out:
# /bin/bash: ./scripts/shrec/train.sh: /usr/bin/env: bad interpreter: Permission denied

# %%
# !python train.py --dataroot datasets/shrec_16 --name shrec16 --ncf 64 128 256 256 --pool_res 600 450 300 180 --norm group --resblocks 1 --flip_edges 0.2 --slide_verts 0.2 --num_aug 20 --niter_decay 100 \
# Out:
# ------------ Options -------------
# arch: mconvnet
# batch_size: 16
# beta1: 0.9
# checkpoints_dir: ./checkpoints
# continue_train: False
# dataroot: datasets/shrec_16
# dataset_mode: classification
# epoch_count: 1
# export_folder:
# fc_n: 100
# flip_edges: 0.2
# gpu_ids: [0]
# init_gain: 0.02
# init_type: normal
# is_train: True
# lr: 0.0002
# lr_decay_iters: 50
# lr_policy: lambda
# max_dataset_size: inf
# name: shrec16
# ncf: [64, 128, 256, 256]
# ninput_edges: 750
# niter: 100
# niter_decay: 100
# no_vis: False
# norm: group
# num_aug: 20
# num_groups: 16
# num_threads: 3
# phase: train
# pool_res: [600, 450, 300, 180]
# print_freq: 10
# resblocks: 1
# run_test_freq: 1
# save_epoch_freq: 1
# save_latest_freq: 250
# scale_verts: False
# seed: None
# serial_batches: False
# slide_verts: 0.2
# verbose_plot: False
# which_epoch: latest
# -------------- End ----------------
# computing mean std from train data...
# 0 of 480
# saved:  datasets/shrec_16/mean_std_cache.p
# ...

# %%
# %cd checkpoints
# Out:
# /content/drive/My Drive/meshcnn_project/MeshCNN/checkpoints

# %%
pwd
# Out:
# '/content/drive/My Drive/meshcnn_project/MeshCNN/checkpoints'

# %%
# %cd shrec16
# Out:
# /content/drive/My Drive/meshcnn_project/MeshCNN/checkpoints/shrec16

# %%
# !ls
# Out:
# 100_net.pth  131_net.pth  162_net.pth  193_net.pth  42_net.pth	73_net.pth
# 101_net.pth  132_net.pth  163_net.pth  194_net.pth  43_net.pth	74_net.pth
# 102_net.pth  133_net.pth  164_net.pth  195_net.pth  44_net.pth	75_net.pth
# 103_net.pth  134_net.pth  165_net.pth  196_net.pth  45_net.pth	76_net.pth
# 104_net.pth  135_net.pth  166_net.pth  197_net.pth  46_net.pth	77_net.pth
# 105_net.pth  136_net.pth  167_net.pth  198_net.pth  47_net.pth	78_net.pth
# 106_net.pth  137_net.pth  168_net.pth  199_net.pth  48_net.pth	79_net.pth
# 107_net.pth  138_net.pth  169_net.pth  19_net.pth   49_net.pth	7_net.pth
# 108_net.pth  139_net.pth  16_net.pth   1_net.pth    4_net.pth	80_net.pth
# 109_net.pth  13_net.pth   170_net.pth  200_net.pth  50_net.pth	81_net.pth
# 10_net.pth   140_net.pth  171_net.pth  20_net.pth   51_net.pth	82_net.pth
# 110_net.pth  141_net.pth  172_net.pth  21_net.pth   52_net.pth	83_net.pth
# 111_net.pth  142_net.pth  173_net.pth  22_net.pth   53_net.pth	84_net.pth
# ...

# %%
! ./scripts/shrec/test.sh

# %%
! ./scripts/shrec/view.sh

# %%
! ./scripts/shrec/get_pretrained.sh

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# %tensorboard — logdir runs
